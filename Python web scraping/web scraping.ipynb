# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://digitaldefynd.com/best-data-science-certification-course-tutorial/'

# %%
page = requests.get(url)

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-5T89KDQ\');</script>\n\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<link rel="profile" href="https://gmpg.org/xfn/11" />\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n<title>20 Best Data Science Certification &amp; Courses [2022 JANUARY] [UPDATED]</title><link rel="preload" as="style" href="https://fonts.googleapis.com/css?family=Roboto%3A400%2C700%7CLato%3A400%2C700%7CLato%3A700%2Cregular%7COpen%20Sans%3Aregular%7CLibre%20Franklin%3A500%2C600%7CLibre%20Frank
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5T89KDQ');</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# ...

# %%
 course = soup.findAll(attrs = {'class': 'lwptoc_item_label'})

# %%
course
# Out:
# [<span class="lwptoc_item_label">1. IBM Data Science Certification (Coursera)</span>,
#  <span class="lwptoc_item_label">2. Professional Certificate in Data Science from Harvard University (edX)</span>,
#  <span class="lwptoc_item_label">3. MIT Data Science and Statistics Certificate (edX)</span>,
#  <span class="lwptoc_item_label">4. Post Graduate Data Science Certification Program (IBM – Purdue University)</span>,
#  <span class="lwptoc_item_label">5. The Data Science Course: Complete Data Science Bootcamp (Udemy)</span>,
#  <span class="lwptoc_item_label">6. Python for Data Science and Machine Learning Bootcamp (Udemy)</span>,
#  <span class="lwptoc_item_label">7. Data Science Executive Education Program (Berkeley ExecEd)</span>,
#  <span class="lwptoc_item_label">8. Top Data Science Courses (Udemy)</span>,
#  <span class="lwptoc_item_label">9. Applied Data Science with Python Certification (University of Michigan)</span>,
# ...

# %%
c1 = course[0].text

# %%
#course[0].text.replace('\n' , "")

# %%
c1
# Out:
# '1. IBM Data Science Certification (Coursera)'

# %%
x = c1.split(".")
print(x)
# Out:
# ['1', ' IBM Data Science Certification (Coursera)']

# %%
index = x[0]
index
# Out:
# '1'

# %%
courselist = x[1]
courselist
# Out:
# ' IBM Data Science Certification (Coursera)'

# %%
data = [[url,courselist]]

# %%
data
# Out:
# [['https://digitaldefynd.com/best-data-science-certification-course-tutorial/',
#   ' IBM Data Science Certification (Coursera)']]

# %%
df = pd.DataFrame(data, columns =['url','courselist'])

# %%
df
# Out:
#                                                  url  \
# 0  https://digitaldefynd.com/best-data-science-ce...
#
#                                    courselist
# 0   IBM Data Science Certification (Coursera)
